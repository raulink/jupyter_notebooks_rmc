# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pandas as pd

# Cargar las variables de entorno desde el archivo .env
load_dotenv()

# Obtener los detalles de la conexión desde el archivo .env
MYSQL_USER = os.getenv('MYSQL_USER')
MYSQL_PASSWORD = os.getenv('MYSQL_PASSWORD')
MYSQL_HOST = os.getenv('MYSQL_HOST')
MYSQL_DATABASE = os.getenv('MYSQL_DATABASE')

# Crear la URL de conexión
connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOST}/{MYSQL_DATABASE}'

# Crear el motor de conexión con SQLAlchemy
engine = create_engine(connection_string)

# Realizar la consulta y convertir el resultado en un DataFrame
query = 'SELECT * FROM ingreso'
df = pd.read_sql(query, engine)

# Mostrar el DataFrame
(df)
# Out:
#         id codigo_ingreso fecha_ingreso  \
# 0        1   0000001/2017      1/1/2017
# 1        2   0000001/2017      1/1/2017
# 2        3   0000001/2017      1/1/2017
# 3        4   0000001/2017      1/1/2017
# 4        5   0000001/2017      1/1/2017
# ...    ...            ...           ...
# 8764  8765   0000038/2024     26/3/2024
# 8765  8766   0000039/2024     26/3/2024
# 8766  8767   0000040/2024     26/3/2024
# 8767  8768   0000041/2024     26/3/2024
# 8768  8769   0000042/2024     27/3/2024
#
#                                          motivo_ingreso  \
# 0                                      RECURSOS PROPIOS
# 1                                      RECURSOS PROPIOS
# 2                                      RECURSOS PROPIOS
# 3                                      RECURSOS PROPIOS
# 4                                      RECURSOS PROPIOS
# ...                                                 ...
# 8764  COMPRA DE HERRAMIENTAS  MENORES PARA LINEA MOR...
# 8765  COMPRA DE HERRAMIENTAS  MENORES PARA LINEA MOR...
# 8766  COMPRA DE HERRAMIENTAS  MENORES PARA LINEA MOR...
# 8767  COMPRA DE HERRAMIENTAS  MENORES PARA LINEA MOR...
# 8768  COMPRA DE PERNOS ALLEN PARA SOPORTES DE CAJAS ...
#
#                        gerencia_solicitante       departamento_solicitante  \
# 0                                      None                           None
# 1                                      None                           None
# 2                                      None                           None
# 3                                      None                           None
# 4                                      None                           None
# ...                                     ...                            ...
# 8764  GERENCIA DE OPERACION Y MANTENIMIENTO  DEPARTAMENTO DE MANTENIMIENTO
# 8765  GERENCIA DE OPERACION Y MANTENIMIENTO  DEPARTAMENTO DE MANTENIMIENTO
# 8766  GERENCIA DE OPERACION Y MANTENIMIENTO  DEPARTAMENTO DE MANTENIMIENTO
# 8767  GERENCIA DE OPERACION Y MANTENIMIENTO  DEPARTAMENTO DE MANTENIMIENTO
# 8768  GERENCIA DE OPERACION Y MANTENIMIENTO  DEPARTAMENTO DE MANTENIMIENTO
#
#      ubicacion       tipo_gasto partida_presupuestaria  \
# 0         None  GASTO CORRIENTE   LLANTAS Y NEUMÁTICOS
# 1         None  GASTO CORRIENTE   LLANTAS Y NEUMÁTICOS
# 2         None  GASTO CORRIENTE   LLANTAS Y NEUMÁTICOS
# 3         None  GASTO CORRIENTE   LLANTAS Y NEUMÁTICOS
# 4         None  GASTO CORRIENTE   LLANTAS Y NEUMÁTICOS
# ...        ...              ...                    ...
# 8764      None  GASTO CORRIENTE                  34800
# 8765      None  GASTO CORRIENTE                  39700
# 8766      None  GASTO CORRIENTE                  39800
# 8767      None  GASTO CORRIENTE                  39800
# 8768      None  GASTO CORRIENTE                  39800
#
#                        proveedor  ... unidad_medida         grupo  sub_grupo  \
# 0                           None  ...          None     REPUESTOS  MECANICOS
# 1                           None  ...          None     REPUESTOS  MECANICOS
# 2                           None  ...          None     REPUESTOS  MECANICOS
# 3                           None  ...          None     REPUESTOS  MECANICOS
# 4                           None  ...          None     REPUESTOS  MECANICOS
# ...                          ...  ...           ...           ...        ...
# 8764                  MAIK ROJAS  ...         PIEZA  HERRAMIENTAS  MECANICAS
# 8765                    SRMM SRL  ...         PIEZA       INSUMOS  ELECTRICO
# 8766             FINI LAGER S.A.  ...         PIEZA     REPUESTOS  MECANICOS
# 8767  IMPORTACIONES ANCEDES LTDA  ...         JUEGO  HERRAMIENTAS  MECANICAS
# 8768                   CENTOR HL  ...         PIEZA     REPUESTOS  MECANICOS
#
#      cantidad precio_unitario  costo_historico  cf-iva  importe_calculado  \
# 0          10          365.44          3654.35     NaN            3654.35
# 1          20          302.90          6057.95     NaN            6057.95
# 2           4         1362.06          5448.22     NaN            5448.22
# 3          20         1109.13         22182.69     NaN           22182.69
# 4          90          227.61         20484.84     NaN           20484.84
# ...       ...             ...              ...     ...                ...
# 8764        3           30.00            90.00  -11.70              78.30
# 8765        2            4.00             8.00   -1.04               6.96
# 8766        4           54.00           216.00  -28.08             187.92
# 8767        1          100.00           100.00  -13.00              87.00
# 8768      508            1.17           593.50  -77.16             516.35
#
#            fecha  codigo_partida
# 0     2017-01-01       34300\r\n
# 1     2017-01-01       34300\r\n
# 2     2017-01-01       34300\r\n
# 3     2017-01-01       34300\r\n
# 4     2017-01-01       34300\r\n
# ...          ...             ...
# 8764  2024-03-26            None
# 8765  2024-03-26            None
# 8766  2024-03-26            None
# 8767  2024-03-26            None
# 8768  2024-03-27            None
#
# [8769 rows x 22 columns]
